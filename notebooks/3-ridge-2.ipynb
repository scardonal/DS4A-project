# %% [markdown]
# # Import libraries

# %%
#Import libraries
import joblib
import matplotlib.pyplot    as plt
import numpy                as np
import pandas               as pd
import pickle
import plotly.express       as px
import plotly.graph_objects as go
import re
import seaborn              as sns
import warnings
import sklearn

from sklearn.compose          import ColumnTransformer
from sklearn.datasets         import fetch_openml
from sklearn.impute           import SimpleImputer
from sklearn.metrics          import mean_absolute_percentage_error, mean_absolute_error, r2_score
from sklearn.model_selection  import train_test_split, GridSearchCV
from sklearn.pipeline         import Pipeline
from sklearn.preprocessing    import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.linear_model     import Ridge
from sklearn                  import set_config

set_config(display="diagram")
sns.set_theme(style="white")

# %% [markdown]
# # Read data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read data
raw_data_dir = '/content/drive/MyDrive/DS4A/data/raw/'
interim_data_dir = '/content/drive/MyDrive/DS4A/data/interim/'
procesed_data_dir = '/content/drive/MyDrive/DS4A/data/processed/'
models_dir = '/content/drive/MyDrive/DS4A/models/'

df_train = pd.read_csv(procesed_data_dir+'df_train.csv')
df_test = pd.read_csv(procesed_data_dir+'df_test.csv')

display(df_train.head(5))
display(df_test.head(5))
# Out:
#                          id  start_date    lat     lon        l5        price  \
# 0  zIFYDamawEDtYa6s+vK2Dw==  2021-07-26    NaN     NaN  Santa Fe   72000000.0
# 1  fDrS2glBKkR3xm1b807MWQ==  2021-06-23  4.725 -74.043   Usaquén  381000000.0
# 2  gmtFWD6hMs9hKml0Pkofsw==  2021-02-25  4.728 -74.052       NaN  270000000.0
# 3  CuRDlEanlk0YFwUJgOJhyg==  2020-09-16  4.756 -74.081      Suba  224000000.0
# 4  ReDLfSoQzFKuXg6ui6jFEg==  2020-08-19  4.732 -74.074      Suba  515000000.0
#
#   property_type  bedrooms_prep  bath_prep  area_prep
# 0          Casa            3.0        1.0      224.0
# 1   Apartamento            3.0        2.0       81.0
# 2   Apartamento            2.0        2.0       43.0
# 3   Apartamento            3.0        2.0       72.0
# 4   Apartamento            3.0        2.0      114.0
#                          id  start_date       lat        lon         l5  \
# 0  iIfkO5O2IjUSRC6emKPdzA==  2021-04-16  4.693646 -74.059749       Suba
# 1  urF8fuuKcO/UmkCCqFaIwg==  2021-01-06  4.679000 -74.045000  Chapinero
# 2  DTF/UL17F+9woCfKIJ55/g==  2021-02-02  4.761000 -74.028000    Usaquén
# 3  YPQ0UXrI7ZvRIEg5fprh5w==  2021-03-09  4.673064 -74.058715  Chapinero
# 4  KqBDY7lEsoBXpXA3Zvg8/A==  2021-05-05       NaN        NaN        NaN
#
#           price property_type  bedrooms_prep  bath_prep  area_prep
# 0  1.200000e+09          Casa            1.0        5.0      243.0
# 1  4.400000e+08   Apartamento            2.0        2.0       90.0
# 2  1.700000e+08   Apartamento            2.0        1.0       44.0
# 3  1.600000e+09   Apartamento            2.0        2.0      142.0
# 4  6.500000e+08          Casa            5.0        4.0      400.0

# %%
#Check data types
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28187 entries, 0 to 28186
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             28187 non-null  object
#  1   start_date     28187 non-null  object
#  2   lat            26771 non-null  float64
#  3   lon            26771 non-null  float64
#  4   l5             25344 non-null  object
#  5   price          28187 non-null  float64
#  6   property_type  28187 non-null  object
#  7   bedrooms_prep  24484 non-null  float64
#  8   bath_prep      24251 non-null  float64
#  9   area_prep      28187 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 2.2+ MB

# %%
#Check missing values
df_train.isna().sum()/df_train.shape[0]
# Out:
# id               0.000000
# start_date       0.000000
# lat              0.050236
# lon              0.050236
# l5               0.100862
# price            0.000000
# property_type    0.000000
# bedrooms_prep    0.131373
# bath_prep        0.139639
# area_prep        0.000000
# dtype: float64

# %%
#Drop id and start_date columns
drop_cols = ['id', 'start_date']
df_train = df_train.drop(drop_cols, axis='columns')
df_test = df_test.drop(drop_cols, axis='columns')

# %%
X_train = df_train.drop(['price'], axis='columns')
y_train = np.log(df_train['price'])

X_test = df_test.drop(['price'], axis='columns')
y_test = np.log(df_test['price'])

# %% [markdown]
# # Log-Level regression

# %% [markdown]
# ## Cross-validation and grid search

# %% [markdown]
# Here we will apply different preprocessing and feature extraction pipelines to different subsets of features, using `ColumnTransformer`
#
# The numeric data will standard-scaled after mean or median imputation. The categorical data is one-hot encoded via `OneHotEncoder` after most-frequent imputation, which creates a new category for missing values.
#
# Finally, the preprocessing pipeline is integrated in a full prediction pipeline using `Pipeline`, together with a simple classification model.

# %%
#Preprocessing pipelines for both numeric and categorical data

numeric_features = ['lat', 'lon', 'bath_prep', 'bedrooms_prep', 'area_prep']
cat_features = ['l5', 'property_type']

categoric_transformer = Pipeline(
    [('imputer', SimpleImputer(strategy='most_frequent')),
     ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))]
    )

numeric_transformer = Pipeline(
    [('imputer', SimpleImputer()),
     ('scaler', StandardScaler())]
     )

preprocessor = ColumnTransformer(
    [('num', numeric_transformer, numeric_features),
     ('cat', categoric_transformer, cat_features)],
    )

#Append regressor to preprocessing pipeline. Now we have a full prediction pipeline.
ridge_pipe = Pipeline(
    [('preprocessor', preprocessor), ('ridge', Ridge())]
     )

# %%
#Using grid search to hyperparameters tuning
#We will search for both the imputer strategy of the numeric preprocessing and the regularization parameter

param_grid = {
    "preprocessor__num__imputer__strategy": ["mean", "median"],
    "ridge__alpha": np.linspace(start=0, stop=300, num=100)
    }

scores = ['r2',
          'neg_mean_absolute_error',
          'neg_mean_absolute_percentage_error']

grid_search = GridSearchCV(ridge_pipe, param_grid,
                           cv=10, scoring=scores,
                           refit='r2',
                           n_jobs=-1
                           )

#This is a representation of the pipeline used
grid_search
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['lat',
#                                                                           'lon',
#                                                                           'bath_prep',
#                                                                           'bedrooms_prep',
#                                                                           'area_prep']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_u...
#        230.3030303 , 233.33333333, 236.36363636, 239.39393939,
#        242.42424242, 245.45454545, 248.48484848, 251.51515152,
#        254.54545455, 257.57575758, 260.60606061, 263.63636364,
#        266.66666667, 269.6969697 , 272.72727273, 275.75757576,
#        278.78787879, 281.81818182, 284.84848485, 287.87878788,
#        290.90909091, 293.93939394, 296.96969697, 300.        ])},
#              refit='r2',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_mean_absolute_percentage_error'])

# %%
grid_search.fit(X_train, y_train)

print("Best params:")
print(grid_search.best_params_)
# Out:
# Best params:
# {'preprocessor__num__imputer__strategy': 'mean', 'ridge__alpha': 3.0303030303030303}

# %%
#Cross-validation and grid search results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results = cv_results[["mean_test_r2",
                         "mean_test_neg_mean_absolute_percentage_error",
                         'mean_test_neg_mean_absolute_error',
                         "param_preprocessor__num__imputer__strategy",
                          "param_ridge__alpha"]]
cv_results = cv_results.sort_values("mean_test_r2", ascending=False)
display(cv_results.head())
cv_results.shape
# Out:
#    mean_test_r2  mean_test_neg_mean_absolute_percentage_error  \
# 1      0.772377                                     -0.014174
# 0      0.772360                                     -0.014171
# 6      0.772354                                     -0.014186
# 5      0.772347                                     -0.014184
# 4      0.772339                                     -0.014181
#
#    mean_test_neg_mean_absolute_error  \
# 1                          -0.283974
# 0                          -0.283934
# 6                          -0.284208
# 5                          -0.284164
# 4                          -0.284121
#
#   param_preprocessor__num__imputer__strategy param_ridge__alpha
# 1                                       mean           3.030303
# 0                                       mean                0.0
# 6                                       mean          18.181818
# 5                                       mean          15.151515
# 4                                       mean          12.121212
# (200, 5)

# %%
#Plot the result score
mean_results = cv_results.query('param_preprocessor__num__imputer__strategy == "mean"')

fig, axes = plt.subplots(1, 3, figsize=(25, 5))
sns.lineplot(data=mean_results, x="param_ridge__alpha", y="mean_test_neg_mean_absolute_error", ax=axes[0])
sns.lineplot(data=mean_results, x="param_ridge__alpha", y="mean_test_r2", ax=axes[1])
sns.lineplot(data=mean_results, x="param_ridge__alpha", y="mean_test_neg_mean_absolute_percentage_error", ax=axes[2])

# %% [markdown]
# ## Fit the model in the whole train set

# %%
#The best estimator is a pipeline and it can be use to predict in test set
best_estimator_pipeline = grid_search.best_estimator_
best_estimator_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['lat', 'lon', 'bath_prep',
#                                                    'bedrooms_prep',
#                                                    'area_prep']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['l5', 'property_type'])])),
#                 ('ridge', Ridge(alpha=3.0303030303030303))])

# %%
#Fit ridge regression with preprocessing in train set and predict in test set
best_estimator_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['lat', 'lon', 'bath_prep',
#                                                    'bedrooms_prep',
#                                                    'area_prep']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['l5', 'property_type'])])),
#                 ('ridge', Ridge(alpha=3.0303030303030303))])

# %%
#Extract coefficients of the model
ridge_coef = list(best_estimator_pipeline[1].coef_)

# %%
standar_num = list(best_estimator_pipeline['preprocessor'].transformers_[0][1]['scaler'].get_feature_names_out(numeric_features))
onehot_cat = list(best_estimator_pipeline['preprocessor'].transformers_[1][1]['encoder'].get_feature_names_out(cat_features))
new_feat = standar_num + onehot_cat

# %%
coef_results = pd.DataFrame(list(zip(new_feat, ridge_coef)), columns = ['Feature', 'Coefficient'])
coef_results.loc[:, "Coefficient"] ='$'+ coef_results["Coefficient"].map('{:,.0f}'.format)
coef_results
# Out:
#                   Feature Coefficient
# 0                     lat         $-0
# 1                     lon          $0
# 2               bath_prep          $0
# 3           bedrooms_prep         $-0
# 4               area_prep          $0
# 5       l5_Barrios Unidos          $0
# 6                 l5_Bosa         $-0
# 7            l5_Chapinero          $1
# 8       l5_Ciudad Bolívar         $-0
# 9             l5_Engativa          $0
# 10            l5_Fontibón          $0
# 11             l5_Kennedy         $-0
# 12       l5_La Candelaria          $0
# 13        l5_Los Mártires          $0
# 14       l5_Puente Aranda          $0
# 15  l5_Rafael Uribe Uribe         $-0
# 16       l5_San Cristobal         $-0
# 17            l5_Santa Fe          $0
# 18                l5_Suba          $0
# 19         l5_Teusaquillo          $0
# 20          l5_Tunjuelito         $-0
# 21             l5_Usaquén          $0
# 22                l5_Usme         $-0
# 23     property_type_Casa         $-0

# %%
#Results
y_pred_train = best_estimator_pipeline.predict(X_train)
y_pred_test = best_estimator_pipeline.predict(X_test)

print("MAPE score in train: %.3f" % mean_absolute_percentage_error(y_train, y_pred_train))
print("MAPE score in test: %.3f" % mean_absolute_percentage_error(y_test, y_pred_test))

print("MAE score in train: %.3f" % mean_absolute_error(y_train, y_pred_train))
print("MAE score in test: %.3f" % mean_absolute_error(y_test, y_pred_test))

print("R2 score in train: %.3f" % r2_score(y_train, y_pred_train))
print("R2 score in test: %.3f" % r2_score(y_test, y_pred_test))
# Out:
# MAPE score in train: 0.014
# MAPE score in test: 0.014
# MAE score in train: 0.284
# MAE score in test: 0.288
# R2 score in train: 0.774
# R2 score in test: 0.769

# %%
#Results with price in normal scale
print("MAPE score in train: %.3f" % mean_absolute_percentage_error(np.exp(y_train), np.exp(y_pred_train)))
print("MAPE score in test: %.3f" % mean_absolute_percentage_error(np.exp(y_test), np.exp(y_pred_test)))

print("MAE score in train: %.3f" % mean_absolute_error(np.exp(y_train), np.exp(y_pred_train)))
print("MAE score in test: %.3f" % mean_absolute_error(np.exp(y_test), np.exp(y_pred_test)))

print("R2 score in train: %.3f" % r2_score(np.exp(y_train), np.exp(y_pred_train)))
print("R2 score in test: %.3f" % r2_score(np.exp(y_test), np.exp(y_pred_test)))
# Out:
# MAPE score in train: 0.310
# MAPE score in test: 0.351
# MAE score in train: 214137674.514
# MAE score in test: 222712858.781
# R2 score in train: 0.589
# R2 score in test: 0.579

# %%
#Export model
joblib.dump(best_estimator_pipeline, models_dir+'ridge_model_2.joblib')
# Out:
# ['/content/drive/MyDrive/DS4A/models/ridge_model_2.joblib']
